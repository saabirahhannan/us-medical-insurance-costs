# %% [markdown]
# # U.S. Medical Insurance Costs
#
# In this project, I will be analyzing the data from a **csv** file called **insurance.csv** using Python fundamentals. This file contains medical insurance costs for patients, along with other variables such as age, sex, etc, which affect the cost. By analyzing the various variables and thus learning more about the patient information, a variety of potential use cases for the data can be discovered.

# %% [markdown]
# To start off, data from the **insurance.csv** file will need to be used, so I will import the `csv` library for this purpose.

# %%
# Import csv library
import csv

# %% [markdown]
# Before actually starting off with Python, initial exploratory analysis is greatly helpful to help acquaint myself with the data. To do this, I will simply look through the data in the csv file itself. I take note of the following things:
# * the number of records, and the number of variables for each record (explanatory, response variable identification).
# * if there are any missing variables.
# * the type of variables (numerical, categorical, etc).
#
# Investigating these aspects will help in thinking critically before importing all the data from the **insurance.csv** file into different lists created for each variable in Python. It helps to plan things out more effectively.
#
# Having mentioned this, I will proceed to create seven empty lists in Python for each of the seven variables identified in the csv file. In addition, I will be creating a list to contain serial numbers for each of the patients. This will be helpful when having to create a dictionary of the people later on.

# %%
# Create empty lists for the different variables, which will soon be populated using the info from insurance.csv
age = []
sex = []
bmi = []
num_of_children = []
smoker = []
region = []
insurance_cost = []

# %% [markdown]
# Since I looked through the **insurance.csv** file, let me go into a little more depth about what I discovered. There were records for a total of 1338 individuals.
# As mentioned earlier, there were a total of 7 variables, namely:
# * *Age* - states the age of the individual. Is a numerical variable with ages ranging from 18 to 64 years.
# * *Sex* - a binary variable taking values of either "male" or "female" which states the gender of the person.
# * *BMI* - depicts the Body Mass Index of a person. A numerical variable with values ranging from 15.96 to 53.13.
# * *Children* - a categorical variable which shows the number of children an individual has. The categories range from 0 to 5 children.
# * *Smoker* - a binary variable taking values of either "yes" or "no" which states whether a person is a smoker or not.
# * *Region* - a categorical variable with 4 possible classes of "northeast", "northwest", "southeast", or "southwest" which states the region the person hails from.
# * *Charges* - a numerical variable containing the yearly medical insurance cost of a person. The costs range from 1121.8739 dollars to 63770.42801 dollars per year.
#
# *Charges* is the dependent variable, while all the other variables are explanatory. It was also noted that there was no missing data so no form of data imputation was required. The data from each column is ready to be imported into their respective empty lists.

# %% [markdown]
# Before importing, an additional list will be created to contain serial numbers for each person. The serial numbers will help to uniquely number each individual. The list will be simply called `serial_number`

# %%
serial_number = list(range(1, 1339))

# %% [markdown]
# Now we are ready to import data from **insurance.csv** into the other 7 empty cells.

# %%
with open("insurance.csv") as insurance_csv:           # opens csv file
    insurance_reader = csv.DictReader(insurance_csv)   # reads the data from the csv file
    for row in insurance_reader:                       # loops through the data in each row of the csv
        age.append(row["age"])                         # adds the data for the specified variable, to its respective list

with open("insurance.csv") as insurance_csv:
    insurance_reader = csv.DictReader(insurance_csv)
    for row in insurance_reader:
        sex.append(row["sex"])

with open("insurance.csv") as insurance_csv:
    insurance_reader = csv.DictReader(insurance_csv)
    for row in insurance_reader:
        bmi.append(row["bmi"])

with open("insurance.csv") as insurance_csv:
    insurance_reader = csv.DictReader(insurance_csv)
    for row in insurance_reader:
        num_of_children.append(row["children"])

with open("insurance.csv") as insurance_csv:
    insurance_reader = csv.DictReader(insurance_csv)
    for row in insurance_reader:
        smoker.append(row["smoker"])

with open("insurance.csv") as insurance_csv:
    insurance_reader = csv.DictReader(insurance_csv)
    for row in insurance_reader:
        region.append(row["region"])

with open("insurance.csv") as insurance_csv:
    insurance_reader = csv.DictReader(insurance_csv)
    for row in insurance_reader:
        insurance_cost.append(row["charges"])

# %% [markdown]
# The data is now loaded into neatly labelled lists and is ready for analysis purposes. Now I must plan out the scope of my analysis. While there are numerous possible areas of analysis, in this project I have decided to focus on the following areas:
# * Creating a dictionary containing the info of all the people in the dataset
# * Identifying the average age of a person
# * Identifying the average yearly insurance cost of a person
# * Identifying if there is a balanced representation of males vs. females in the dataset
#
# To carry out these 4 different analyses, firstly, we create a class called `Person_info` which will be comprised of 4 methods, each of which will be used to achieve one of the above stated goals. The methods are namely:
# * `compile_dictionary()`
# * `analyze_ages()`
# * `analyze_insurance_cost()`
# * `analyze_gender()`
#
# Building of the classes and the methods is shown below:

# %%
# Start the new class containing all the different methods for each of our 4 analyses
class Person_info:
    # specify the init method with all the list parameters. These will be used in the upcoming methods
    def __init__(self, serial_number, age, sex, bmi, num_of_children, smoker, region, insurance_cost):
        self.serial_number = serial_number
        self.age = age
        self.sex = sex
        self.bmi = bmi
        self.num_of_children = num_of_children
        self.smoker = smoker
        self.region = region
        self.insurance_cost = insurance_cost
    
    # method to compile all the individuals' information in a single dictionary
    def compile_dictionary(self):
        # create an empty dictionary
        self.personal_info = {}
        # iterate through the different lists for the data regarding the person based on their index number, denoted by "i" 
        for i in range(len(self.serial_number)):
            # dictionary keys are the unique serial numbers  
            # dictionary values are dictionaries themselves containing a key for each piece of data
            self.personal_info[self.serial_number[i]] = {"Record No": self.serial_number[i], "Age": self.age[i], 
                                                         "Gender": self.sex[i], "BMI": self.bmi[i], 
                                                         "No. of children": self.num_of_children[i], "Smoker": self.smoker[i], 
                                                         "Region": self.region[i], 
                                                         "Yearly Insurance Cost": self.insurance_cost[i]}
        # return the compiled, comprehensive dictionary
        return self.personal_info
    
    # method to identify the average ages of all the people in insurance.csv
    def analyze_ages(self):
        # initialize the total age at 0
        total_age = 0
        # iterate through the list of ages
        for age in self.age:
            # find the sum of the total age in each iteration
            total_age += int(age)
            # now calculate average age, which is the total age divided by the number of instances in the list
            average_age = (total_age / len(self.age))
        # return the average age of a person
        return("Average age: " + str(average_age) + " years")
    
    # method to identify the average insurance costs of all the people in insurance.csv
    def analyze_insurance_cost(self):
        # initialize the total cost at 0
        total_cost = 0
        # iterate through the list of costs
        for cost in self.insurance_cost:
            # find the sum of the total cost in each iteration
            total_cost += float(cost)
            # now calculate the average insurance cost, 
            # average cost is the total cost divided by the number of instances in the list
            average_cost = (total_cost / len(self.insurance_cost))
        # return the average insurance cost of a person
        return("Average yearly insurance cost: " + str(average_cost) + " dollars")
    
    # method to calculate the number of males and females in insurance.csv
    def analyze_gender(self):
        # initialize the number of males and females to 0
        males = 0
        females = 0
        # iterate through the list containing the sex of each person
        for gender in self.sex:
            # if the gender is female, add to the number of females, incrementally
            if gender == "female":
                females += 1
            # otherwise, if it is male, add to the number of males, incrementally
            elif gender == "male":
                males += 1
        # print out the number of people in each gender
        print("Number of females: ", females)
        print("Number of males: ", males)

# %% [markdown]
# Once all the different methods have been written out and defined within the class, it is time to run each method in turn and obtain the results of each individual analysis and eventually, interpret the findings. An instance of the class called `person_info` will be created for this purpose. The parameters specified within the parentheses will be the names of the 8 lists we have now.

# %%
person_info = Person_info(serial_number, age, sex, bmi, num_of_children, smoker, region, insurance_cost)

# %%
person_info.compile_dictionary()
# Out:
# {1: {'Record No': 1,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '27.9',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '16884.924'},
#  2: {'Record No': 2,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '33.77',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '1725.5523'},
#  3: {'Record No': 3,
#   'Age': '28',
#   'Gender': 'male',
#   'BMI': '33',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '4449.462'},
#  4: {'Record No': 4,
#   'Age': '33',
#   'Gender': 'male',
#   'BMI': '22.705',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '21984.47061'},
#  5: {'Record No': 5,
#   'Age': '32',
#   'Gender': 'male',
#   'BMI': '28.88',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '3866.8552'},
#  6: {'Record No': 6,
#   'Age': '31',
#   'Gender': 'female',
#   'BMI': '25.74',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '3756.6216'},
#  7: {'Record No': 7,
#   'Age': '46',
#   'Gender': 'female',
#   'BMI': '33.44',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '8240.5896'},
#  8: {'Record No': 8,
#   'Age': '37',
#   'Gender': 'female',
#   'BMI': '27.74',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '7281.5056'},
#  9: {'Record No': 9,
#   'Age': '37',
#   'Gender': 'male',
#   'BMI': '29.83',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '6406.4107'},
#  10: {'Record No': 10,
#   'Age': '60',
#   'Gender': 'female',
#   'BMI': '25.84',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '28923.13692'},
#  11: {'Record No': 11,
#   'Age': '25',
#   'Gender': 'male',
#   'BMI': '26.22',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '2721.3208'},
#  12: {'Record No': 12,
#   'Age': '62',
#   'Gender': 'female',
#   'BMI': '26.29',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '27808.7251'},
#  13: {'Record No': 13,
#   'Age': '23',
#   'Gender': 'male',
#   'BMI': '34.4',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1826.843'},
#  14: {'Record No': 14,
#   'Age': '56',
#   'Gender': 'female',
#   'BMI': '39.82',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '11090.7178'},
#  15: {'Record No': 15,
#   'Age': '27',
#   'Gender': 'male',
#   'BMI': '42.13',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '39611.7577'},
#  16: {'Record No': 16,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '24.6',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1837.237'},
#  17: {'Record No': 17,
#   'Age': '52',
#   'Gender': 'female',
#   'BMI': '30.78',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '10797.3362'},
#  18: {'Record No': 18,
#   'Age': '23',
#   'Gender': 'male',
#   'BMI': '23.845',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '2395.17155'},
#  19: {'Record No': 19,
#   'Age': '56',
#   'Gender': 'male',
#   'BMI': '40.3',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '10602.385'},
#  20: {'Record No': 20,
#   'Age': '30',
#   'Gender': 'male',
#   'BMI': '35.3',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '36837.467'},
#  21: {'Record No': 21,
#   'Age': '60',
#   'Gender': 'female',
#   'BMI': '36.005',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '13228.84695'},
#  22: {'Record No': 22,
#   'Age': '30',
#   'Gender': 'female',
#   'BMI': '32.4',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '4149.736'},
#  23: {'Record No': 23,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '34.1',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '1137.011'},
#  24: {'Record No': 24,
#   'Age': '34',
#   'Gender': 'female',
#   'BMI': '31.92',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '37701.8768'},
#  25: {'Record No': 25,
#   'Age': '37',
#   'Gender': 'male',
#   'BMI': '28.025',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6203.90175'},
#  26: {'Record No': 26,
#   'Age': '59',
#   'Gender': 'female',
#   'BMI': '27.72',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '14001.1338'},
#  27: {'Record No': 27,
#   'Age': '63',
#   'Gender': 'female',
#   'BMI': '23.085',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '14451.83515'},
#  28: {'Record No': 28,
#   'Age': '55',
#   'Gender': 'female',
#   'BMI': '32.775',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '12268.63225'},
#  29: {'Record No': 29,
#   'Age': '23',
#   'Gender': 'male',
#   'BMI': '17.385',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2775.19215'},
#  30: {'Record No': 30,
#   'Age': '31',
#   'Gender': 'male',
#   'BMI': '36.3',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '38711'},
#  31: {'Record No': 31,
#   'Age': '22',
#   'Gender': 'male',
#   'BMI': '35.6',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '35585.576'},
#  32: {'Record No': 32,
#   'Age': '18',
#   'Gender': 'female',
#   'BMI': '26.315',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '2198.18985'},
#  33: {'Record No': 33,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '28.6',
#   'No. of children': '5',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '4687.797'},
#  34: {'Record No': 34,
#   'Age': '63',
#   'Gender': 'male',
#   'BMI': '28.31',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '13770.0979'},
#  35: {'Record No': 35,
#   'Age': '28',
#   'Gender': 'male',
#   'BMI': '36.4',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '51194.55914'},
#  36: {'Record No': 36,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '20.425',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '1625.43375'},
#  37: {'Record No': 37,
#   'Age': '62',
#   'Gender': 'female',
#   'BMI': '32.965',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '15612.19335'},
#  38: {'Record No': 38,
#   'Age': '26',
#   'Gender': 'male',
#   'BMI': '20.8',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '2302.3'},
#  39: {'Record No': 39,
#   'Age': '35',
#   'Gender': 'male',
#   'BMI': '36.67',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '39774.2763'},
#  40: {'Record No': 40,
#   'Age': '60',
#   'Gender': 'male',
#   'BMI': '39.9',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '48173.361'},
#  41: {'Record No': 41,
#   'Age': '24',
#   'Gender': 'female',
#   'BMI': '26.6',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '3046.062'},
#  42: {'Record No': 42,
#   'Age': '31',
#   'Gender': 'female',
#   'BMI': '36.63',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '4949.7587'},
#  43: {'Record No': 43,
#   'Age': '41',
#   'Gender': 'male',
#   'BMI': '21.78',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '6272.4772'},
#  44: {'Record No': 44,
#   'Age': '37',
#   'Gender': 'female',
#   'BMI': '30.8',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '6313.759'},
#  45: {'Record No': 45,
#   'Age': '38',
#   'Gender': 'male',
#   'BMI': '37.05',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '6079.6715'},
#  46: {'Record No': 46,
#   'Age': '55',
#   'Gender': 'male',
#   'BMI': '37.3',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '20630.28351'},
#  47: {'Record No': 47,
#   'Age': '18',
#   'Gender': 'female',
#   'BMI': '38.665',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '3393.35635'},
#  48: {'Record No': 48,
#   'Age': '28',
#   'Gender': 'female',
#   'BMI': '34.77',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '3556.9223'},
#  49: {'Record No': 49,
#   'Age': '60',
#   'Gender': 'female',
#   'BMI': '24.53',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '12629.8967'},
#  50: {'Record No': 50,
#   'Age': '36',
#   'Gender': 'male',
#   'BMI': '35.2',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '38709.176'},
#  51: {'Record No': 51,
#   'Age': '18',
#   'Gender': 'female',
#   'BMI': '35.625',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '2211.13075'},
#  52: {'Record No': 52,
#   'Age': '21',
#   'Gender': 'female',
#   'BMI': '33.63',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '3579.8287'},
#  53: {'Record No': 53,
#   'Age': '48',
#   'Gender': 'male',
#   'BMI': '28',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '23568.272'},
#  54: {'Record No': 54,
#   'Age': '36',
#   'Gender': 'male',
#   'BMI': '34.43',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '37742.5757'},
#  55: {'Record No': 55,
#   'Age': '40',
#   'Gender': 'female',
#   'BMI': '28.69',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '8059.6791'},
#  56: {'Record No': 56,
#   'Age': '58',
#   'Gender': 'male',
#   'BMI': '36.955',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '47496.49445'},
#  57: {'Record No': 57,
#   'Age': '58',
#   'Gender': 'female',
#   'BMI': '31.825',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '13607.36875'},
#  58: {'Record No': 58,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '31.68',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '34303.1672'},
#  59: {'Record No': 59,
#   'Age': '53',
#   'Gender': 'female',
#   'BMI': '22.88',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '23244.7902'},
#  60: {'Record No': 60,
#   'Age': '34',
#   'Gender': 'female',
#   'BMI': '37.335',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '5989.52365'},
#  61: {'Record No': 61,
#   'Age': '43',
#   'Gender': 'male',
#   'BMI': '27.36',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '8606.2174'},
#  62: {'Record No': 62,
#   'Age': '25',
#   'Gender': 'male',
#   'BMI': '33.66',
#   'No. of children': '4',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '4504.6624'},
#  63: {'Record No': 63,
#   'Age': '64',
#   'Gender': 'male',
#   'BMI': '24.7',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '30166.61817'},
#  64: {'Record No': 64,
#   'Age': '28',
#   'Gender': 'female',
#   'BMI': '25.935',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '4133.64165'},
#  65: {'Record No': 65,
#   'Age': '20',
#   'Gender': 'female',
#   'BMI': '22.42',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '14711.7438'},
#  66: {'Record No': 66,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '28.9',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1743.214'},
#  67: {'Record No': 67,
#   'Age': '61',
#   'Gender': 'female',
#   'BMI': '39.1',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '14235.072'},
#  68: {'Record No': 68,
#   'Age': '40',
#   'Gender': 'male',
#   'BMI': '26.315',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6389.37785'},
#  69: {'Record No': 69,
#   'Age': '40',
#   'Gender': 'female',
#   'BMI': '36.19',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '5920.1041'},
#  70: {'Record No': 70,
#   'Age': '28',
#   'Gender': 'male',
#   'BMI': '23.98',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '17663.1442'},
#  71: {'Record No': 71,
#   'Age': '27',
#   'Gender': 'female',
#   'BMI': '24.75',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '16577.7795'},
#  72: {'Record No': 72,
#   'Age': '31',
#   'Gender': 'male',
#   'BMI': '28.5',
#   'No. of children': '5',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '6799.458'},
#  73: {'Record No': 73,
#   'Age': '53',
#   'Gender': 'female',
#   'BMI': '28.1',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '11741.726'},
#  74: {'Record No': 74,
#   'Age': '58',
#   'Gender': 'male',
#   'BMI': '32.01',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '11946.6259'},
#  75: {'Record No': 75,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '27.4',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7726.854'},
#  76: {'Record No': 76,
#   'Age': '57',
#   'Gender': 'male',
#   'BMI': '34.01',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '11356.6609'},
#  77: {'Record No': 77,
#   'Age': '29',
#   'Gender': 'female',
#   'BMI': '29.59',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '3947.4131'},
#  78: {'Record No': 78,
#   'Age': '21',
#   'Gender': 'male',
#   'BMI': '35.53',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '1532.4697'},
#  79: {'Record No': 79,
#   'Age': '22',
#   'Gender': 'female',
#   'BMI': '39.805',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '2755.02095'},
#  80: {'Record No': 80,
#   'Age': '41',
#   'Gender': 'female',
#   'BMI': '32.965',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6571.02435'},
#  81: {'Record No': 81,
#   'Age': '31',
#   'Gender': 'male',
#   'BMI': '26.885',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4441.21315'},
#  82: {'Record No': 82,
#   'Age': '45',
#   'Gender': 'female',
#   'BMI': '38.285',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '7935.29115'},
#  83: {'Record No': 83,
#   'Age': '22',
#   'Gender': 'male',
#   'BMI': '37.62',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '37165.1638'},
#  84: {'Record No': 84,
#   'Age': '48',
#   'Gender': 'female',
#   'BMI': '41.23',
#   'No. of children': '4',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '11033.6617'},
#  85: {'Record No': 85,
#   'Age': '37',
#   'Gender': 'female',
#   'BMI': '34.8',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '39836.519'},
#  86: {'Record No': 86,
#   'Age': '45',
#   'Gender': 'male',
#   'BMI': '22.895',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '21098.55405'},
#  87: {'Record No': 87,
#   'Age': '57',
#   'Gender': 'female',
#   'BMI': '31.16',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '43578.9394'},
#  88: {'Record No': 88,
#   'Age': '56',
#   'Gender': 'female',
#   'BMI': '27.2',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '11073.176'},
#  89: {'Record No': 89,
#   'Age': '46',
#   'Gender': 'female',
#   'BMI': '27.74',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '8026.6666'},
#  90: {'Record No': 90,
#   'Age': '55',
#   'Gender': 'female',
#   'BMI': '26.98',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '11082.5772'},
#  91: {'Record No': 91,
#   'Age': '21',
#   'Gender': 'female',
#   'BMI': '39.49',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2026.9741'},
#  92: {'Record No': 92,
#   'Age': '53',
#   'Gender': 'female',
#   'BMI': '24.795',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '10942.13205'},
#  93: {'Record No': 93,
#   'Age': '59',
#   'Gender': 'male',
#   'BMI': '29.83',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '30184.9367'},
#  94: {'Record No': 94,
#   'Age': '35',
#   'Gender': 'male',
#   'BMI': '34.77',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '5729.0053'},
#  95: {'Record No': 95,
#   'Age': '64',
#   'Gender': 'female',
#   'BMI': '31.3',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '47291.055'},
#  96: {'Record No': 96,
#   'Age': '28',
#   'Gender': 'female',
#   'BMI': '37.62',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '3766.8838'},
#  97: {'Record No': 97,
#   'Age': '54',
#   'Gender': 'female',
#   'BMI': '30.8',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '12105.32'},
#  98: {'Record No': 98,
#   'Age': '55',
#   'Gender': 'male',
#   'BMI': '38.28',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '10226.2842'},
#  99: {'Record No': 99,
#   'Age': '56',
#   'Gender': 'male',
#   'BMI': '19.95',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '22412.6485'},
#  100: {'Record No': 100,
#   'Age': '38',
#   'Gender': 'male',
#   'BMI': '19.3',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '15820.699'},
#  101: {'Record No': 101,
#   'Age': '41',
#   'Gender': 'female',
#   'BMI': '31.6',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '6186.127'},
#  102: {'Record No': 102,
#   'Age': '30',
#   'Gender': 'male',
#   'BMI': '25.46',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '3645.0894'},
#  103: {'Record No': 103,
#   'Age': '18',
#   'Gender': 'female',
#   'BMI': '30.115',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '21344.8467'},
#  104: {'Record No': 104,
#   'Age': '61',
#   'Gender': 'female',
#   'BMI': '29.92',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '30942.1918'},
#  105: {'Record No': 105,
#   'Age': '34',
#   'Gender': 'female',
#   'BMI': '27.5',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '5003.853'},
#  106: {'Record No': 106,
#   'Age': '20',
#   'Gender': 'male',
#   'BMI': '28.025',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '17560.37975'},
#  107: {'Record No': 107,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '28.4',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '2331.519'},
#  108: {'Record No': 108,
#   'Age': '26',
#   'Gender': 'male',
#   'BMI': '30.875',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '3877.30425'},
#  109: {'Record No': 109,
#   'Age': '29',
#   'Gender': 'male',
#   'BMI': '27.94',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2867.1196'},
#  110: {'Record No': 110,
#   'Age': '63',
#   'Gender': 'male',
#   'BMI': '35.09',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '47055.5321'},
#  111: {'Record No': 111,
#   'Age': '54',
#   'Gender': 'male',
#   'BMI': '33.63',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '10825.2537'},
#  112: {'Record No': 112,
#   'Age': '55',
#   'Gender': 'female',
#   'BMI': '29.7',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '11881.358'},
#  113: {'Record No': 113,
#   'Age': '37',
#   'Gender': 'male',
#   'BMI': '30.8',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '4646.759'},
#  114: {'Record No': 114,
#   'Age': '21',
#   'Gender': 'female',
#   'BMI': '35.72',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2404.7338'},
#  115: {'Record No': 115,
#   'Age': '52',
#   'Gender': 'male',
#   'BMI': '32.205',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '11488.31695'},
#  116: {'Record No': 116,
#   'Age': '60',
#   'Gender': 'male',
#   'BMI': '28.595',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '30259.99556'},
#  117: {'Record No': 117,
#   'Age': '58',
#   'Gender': 'male',
#   'BMI': '49.06',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '11381.3254'},
#  118: {'Record No': 118,
#   'Age': '29',
#   'Gender': 'female',
#   'BMI': '27.94',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '19107.7796'},
#  119: {'Record No': 119,
#   'Age': '49',
#   'Gender': 'female',
#   'BMI': '27.17',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '8601.3293'},
#  120: {'Record No': 120,
#   'Age': '37',
#   'Gender': 'female',
#   'BMI': '23.37',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6686.4313'},
#  121: {'Record No': 121,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '37.1',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7740.337'},
#  122: {'Record No': 122,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '23.75',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '1705.6245'},
#  123: {'Record No': 123,
#   'Age': '20',
#   'Gender': 'female',
#   'BMI': '28.975',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2257.47525'},
#  124: {'Record No': 124,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '31.35',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '39556.4945'},
#  125: {'Record No': 125,
#   'Age': '47',
#   'Gender': 'female',
#   'BMI': '33.915',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '10115.00885'},
#  126: {'Record No': 126,
#   'Age': '26',
#   'Gender': 'female',
#   'BMI': '28.785',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '3385.39915'},
#  127: {'Record No': 127,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '28.3',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '17081.08'},
#  128: {'Record No': 128,
#   'Age': '52',
#   'Gender': 'female',
#   'BMI': '37.4',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '9634.538'},
#  129: {'Record No': 129,
#   'Age': '32',
#   'Gender': 'female',
#   'BMI': '17.765',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '32734.1863'},
#  130: {'Record No': 130,
#   'Age': '38',
#   'Gender': 'male',
#   'BMI': '34.7',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '6082.405'},
#  131: {'Record No': 131,
#   'Age': '59',
#   'Gender': 'female',
#   'BMI': '26.505',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '12815.44495'},
#  132: {'Record No': 132,
#   'Age': '61',
#   'Gender': 'female',
#   'BMI': '22.04',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '13616.3586'},
#  133: {'Record No': 133,
#   'Age': '53',
#   'Gender': 'female',
#   'BMI': '35.9',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '11163.568'},
#  134: {'Record No': 134,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '25.555',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '1632.56445'},
#  135: {'Record No': 135,
#   'Age': '20',
#   'Gender': 'female',
#   'BMI': '28.785',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '2457.21115'},
#  136: {'Record No': 136,
#   'Age': '22',
#   'Gender': 'female',
#   'BMI': '28.05',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2155.6815'},
#  137: {'Record No': 137,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '34.1',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1261.442'},
#  138: {'Record No': 138,
#   'Age': '22',
#   'Gender': 'male',
#   'BMI': '25.175',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2045.68525'},
#  139: {'Record No': 139,
#   'Age': '54',
#   'Gender': 'female',
#   'BMI': '31.9',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '27322.73386'},
#  140: {'Record No': 140,
#   'Age': '22',
#   'Gender': 'female',
#   'BMI': '36',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '2166.732'},
#  141: {'Record No': 141,
#   'Age': '34',
#   'Gender': 'male',
#   'BMI': '22.42',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '27375.90478'},
#  142: {'Record No': 142,
#   'Age': '26',
#   'Gender': 'male',
#   'BMI': '32.49',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '3490.5491'},
#  143: {'Record No': 143,
#   'Age': '34',
#   'Gender': 'male',
#   'BMI': '25.3',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '18972.495'},
#  144: {'Record No': 144,
#   'Age': '29',
#   'Gender': 'male',
#   'BMI': '29.735',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '18157.876'},
#  145: {'Record No': 145,
#   'Age': '30',
#   'Gender': 'male',
#   'BMI': '28.69',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '20745.9891'},
#  146: {'Record No': 146,
#   'Age': '29',
#   'Gender': 'female',
#   'BMI': '38.83',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '5138.2567'},
#  147: {'Record No': 147,
#   'Age': '46',
#   'Gender': 'male',
#   'BMI': '30.495',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '40720.55105'},
#  148: {'Record No': 148,
#   'Age': '51',
#   'Gender': 'female',
#   'BMI': '37.73',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '9877.6077'},
#  149: {'Record No': 149,
#   'Age': '53',
#   'Gender': 'female',
#   'BMI': '37.43',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '10959.6947'},
#  150: {'Record No': 150,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '28.4',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1842.519'},
#  151: {'Record No': 151,
#   'Age': '35',
#   'Gender': 'male',
#   'BMI': '24.13',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '5125.2157'},
#  152: {'Record No': 152,
#   'Age': '48',
#   'Gender': 'male',
#   'BMI': '29.7',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '7789.635'},
#  153: {'Record No': 153,
#   'Age': '32',
#   'Gender': 'female',
#   'BMI': '37.145',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '6334.34355'},
#  154: {'Record No': 154,
#   'Age': '42',
#   'Gender': 'female',
#   'BMI': '23.37',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '19964.7463'},
#  155: {'Record No': 155,
#   'Age': '40',
#   'Gender': 'female',
#   'BMI': '25.46',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '7077.1894'},
#  156: {'Record No': 156,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '39.52',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6948.7008'},
#  157: {'Record No': 157,
#   'Age': '48',
#   'Gender': 'male',
#   'BMI': '24.42',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '21223.6758'},
#  158: {'Record No': 158,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '25.175',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '15518.18025'},
#  159: {'Record No': 159,
#   'Age': '30',
#   'Gender': 'male',
#   'BMI': '35.53',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '36950.2567'},
#  160: {'Record No': 160,
#   'Age': '50',
#   'Gender': 'female',
#   'BMI': '27.83',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '19749.38338'},
#  161: {'Record No': 161,
#   'Age': '42',
#   'Gender': 'female',
#   'BMI': '26.6',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '21348.706'},
#  162: {'Record No': 162,
#   'Age': '18',
#   'Gender': 'female',
#   'BMI': '36.85',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '36149.4835'},
#  163: {'Record No': 163,
#   'Age': '54',
#   'Gender': 'male',
#   'BMI': '39.6',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '10450.552'},
#  164: {'Record No': 164,
#   'Age': '32',
#   'Gender': 'female',
#   'BMI': '29.8',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '5152.134'},
#  165: {'Record No': 165,
#   'Age': '37',
#   'Gender': 'male',
#   'BMI': '29.64',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '5028.1466'},
#  166: {'Record No': 166,
#   'Age': '47',
#   'Gender': 'male',
#   'BMI': '28.215',
#   'No. of children': '4',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '10407.08585'},
#  167: {'Record No': 167,
#   'Age': '20',
#   'Gender': 'female',
#   'BMI': '37',
#   'No. of children': '5',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '4830.63'},
#  168: {'Record No': 168,
#   'Age': '32',
#   'Gender': 'female',
#   'BMI': '33.155',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6128.79745'},
#  169: {'Record No': 169,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '31.825',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2719.27975'},
#  170: {'Record No': 170,
#   'Age': '27',
#   'Gender': 'male',
#   'BMI': '18.905',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4827.90495'},
#  171: {'Record No': 171,
#   'Age': '63',
#   'Gender': 'male',
#   'BMI': '41.47',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '13405.3903'},
#  172: {'Record No': 172,
#   'Age': '49',
#   'Gender': 'male',
#   'BMI': '30.3',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '8116.68'},
#  173: {'Record No': 173,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '15.96',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '1694.7964'},
#  174: {'Record No': 174,
#   'Age': '35',
#   'Gender': 'female',
#   'BMI': '34.8',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '5246.047'},
#  175: {'Record No': 175,
#   'Age': '24',
#   'Gender': 'female',
#   'BMI': '33.345',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2855.43755'},
#  176: {'Record No': 176,
#   'Age': '63',
#   'Gender': 'female',
#   'BMI': '37.7',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '48824.45'},
#  177: {'Record No': 177,
#   'Age': '38',
#   'Gender': 'male',
#   'BMI': '27.835',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6455.86265'},
#  178: {'Record No': 178,
#   'Age': '54',
#   'Gender': 'male',
#   'BMI': '29.2',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '10436.096'},
#  179: {'Record No': 179,
#   'Age': '46',
#   'Gender': 'female',
#   'BMI': '28.9',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '8823.279'},
#  180: {'Record No': 180,
#   'Age': '41',
#   'Gender': 'female',
#   'BMI': '33.155',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '8538.28845'},
#  181: {'Record No': 181,
#   'Age': '58',
#   'Gender': 'male',
#   'BMI': '28.595',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '11735.87905'},
#  182: {'Record No': 182,
#   'Age': '18',
#   'Gender': 'female',
#   'BMI': '38.28',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '1631.8212'},
#  183: {'Record No': 183,
#   'Age': '22',
#   'Gender': 'male',
#   'BMI': '19.95',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4005.4225'},
#  184: {'Record No': 184,
#   'Age': '44',
#   'Gender': 'female',
#   'BMI': '26.41',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '7419.4779'},
#  185: {'Record No': 185,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '30.69',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '7731.4271'},
#  186: {'Record No': 186,
#   'Age': '36',
#   'Gender': 'male',
#   'BMI': '41.895',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '43753.33705'},
#  187: {'Record No': 187,
#   'Age': '26',
#   'Gender': 'female',
#   'BMI': '29.92',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '3981.9768'},
#  188: {'Record No': 188,
#   'Age': '30',
#   'Gender': 'female',
#   'BMI': '30.9',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '5325.651'},
#  189: {'Record No': 189,
#   'Age': '41',
#   'Gender': 'female',
#   'BMI': '32.2',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '6775.961'},
#  190: {'Record No': 190,
#   'Age': '29',
#   'Gender': 'female',
#   'BMI': '32.11',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '4922.9159'},
#  191: {'Record No': 191,
#   'Age': '61',
#   'Gender': 'male',
#   'BMI': '31.57',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '12557.6053'},
#  192: {'Record No': 192,
#   'Age': '36',
#   'Gender': 'female',
#   'BMI': '26.2',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '4883.866'},
#  193: {'Record No': 193,
#   'Age': '25',
#   'Gender': 'male',
#   'BMI': '25.74',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2137.6536'},
#  194: {'Record No': 194,
#   'Age': '56',
#   'Gender': 'female',
#   'BMI': '26.6',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '12044.342'},
#  195: {'Record No': 195,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '34.43',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '1137.4697'},
#  196: {'Record No': 196,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '30.59',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '1639.5631'},
#  197: {'Record No': 197,
#   'Age': '39',
#   'Gender': 'female',
#   'BMI': '32.8',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '5649.715'},
#  198: {'Record No': 198,
#   'Age': '45',
#   'Gender': 'female',
#   'BMI': '28.6',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '8516.829'},
#  199: {'Record No': 199,
#   'Age': '51',
#   'Gender': 'female',
#   'BMI': '18.05',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '9644.2525'},
#  200: {'Record No': 200,
#   'Age': '64',
#   'Gender': 'female',
#   'BMI': '39.33',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '14901.5167'},
#  201: {'Record No': 201,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '32.11',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2130.6759'},
#  202: {'Record No': 202,
#   'Age': '48',
#   'Gender': 'female',
#   'BMI': '32.23',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '8871.1517'},
#  203: {'Record No': 203,
#   'Age': '60',
#   'Gender': 'female',
#   'BMI': '24.035',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '13012.20865'},
#  204: {'Record No': 204,
#   'Age': '27',
#   'Gender': 'female',
#   'BMI': '36.08',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '37133.8982'},
#  205: {'Record No': 205,
#   'Age': '46',
#   'Gender': 'male',
#   'BMI': '22.3',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7147.105'},
#  206: {'Record No': 206,
#   'Age': '28',
#   'Gender': 'female',
#   'BMI': '28.88',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4337.7352'},
#  207: {'Record No': 207,
#   'Age': '59',
#   'Gender': 'male',
#   'BMI': '26.4',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '11743.299'},
#  208: {'Record No': 208,
#   'Age': '35',
#   'Gender': 'male',
#   'BMI': '27.74',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '20984.0936'},
#  209: {'Record No': 209,
#   'Age': '63',
#   'Gender': 'female',
#   'BMI': '31.8',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '13880.949'},
#  210: {'Record No': 210,
#   'Age': '40',
#   'Gender': 'male',
#   'BMI': '41.23',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '6610.1097'},
#  211: {'Record No': 211,
#   'Age': '20',
#   'Gender': 'male',
#   'BMI': '33',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1980.07'},
#  212: {'Record No': 212,
#   'Age': '40',
#   'Gender': 'male',
#   'BMI': '30.875',
#   'No. of children': '4',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '8162.71625'},
#  213: {'Record No': 213,
#   'Age': '24',
#   'Gender': 'male',
#   'BMI': '28.5',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '3537.703'},
#  214: {'Record No': 214,
#   'Age': '34',
#   'Gender': 'female',
#   'BMI': '26.73',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '5002.7827'},
#  215: {'Record No': 215,
#   'Age': '45',
#   'Gender': 'female',
#   'BMI': '30.9',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '8520.026'},
#  216: {'Record No': 216,
#   'Age': '41',
#   'Gender': 'female',
#   'BMI': '37.1',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7371.772'},
#  217: {'Record No': 217,
#   'Age': '53',
#   'Gender': 'female',
#   'BMI': '26.6',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '10355.641'},
#  218: {'Record No': 218,
#   'Age': '27',
#   'Gender': 'male',
#   'BMI': '23.1',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2483.736'},
#  219: {'Record No': 219,
#   'Age': '26',
#   'Gender': 'female',
#   'BMI': '29.92',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '3392.9768'},
#  220: {'Record No': 220,
#   'Age': '24',
#   'Gender': 'female',
#   'BMI': '23.21',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '25081.76784'},
#  221: {'Record No': 221,
#   'Age': '34',
#   'Gender': 'female',
#   'BMI': '33.7',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '5012.471'},
#  222: {'Record No': 222,
#   'Age': '53',
#   'Gender': 'female',
#   'BMI': '33.25',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '10564.8845'},
#  223: {'Record No': 223,
#   'Age': '32',
#   'Gender': 'male',
#   'BMI': '30.8',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '5253.524'},
#  224: {'Record No': 224,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '34.8',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '34779.615'},
#  225: {'Record No': 225,
#   'Age': '42',
#   'Gender': 'male',
#   'BMI': '24.64',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '19515.5416'},
#  226: {'Record No': 226,
#   'Age': '55',
#   'Gender': 'male',
#   'BMI': '33.88',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '11987.1682'},
#  227: {'Record No': 227,
#   'Age': '28',
#   'Gender': 'male',
#   'BMI': '38.06',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2689.4954'},
#  228: {'Record No': 228,
#   'Age': '58',
#   'Gender': 'female',
#   'BMI': '41.91',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '24227.33724'},
#  229: {'Record No': 229,
#   'Age': '41',
#   'Gender': 'female',
#   'BMI': '31.635',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '7358.17565'},
#  230: {'Record No': 230,
#   'Age': '47',
#   'Gender': 'male',
#   'BMI': '25.46',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '9225.2564'},
#  231: {'Record No': 231,
#   'Age': '42',
#   'Gender': 'female',
#   'BMI': '36.195',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '7443.64305'},
#  232: {'Record No': 232,
#   'Age': '59',
#   'Gender': 'female',
#   'BMI': '27.83',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '14001.2867'},
#  233: {'Record No': 233,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '17.8',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1727.785'},
#  234: {'Record No': 234,
#   'Age': '59',
#   'Gender': 'male',
#   'BMI': '27.5',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '12333.828'},
#  235: {'Record No': 235,
#   'Age': '39',
#   'Gender': 'male',
#   'BMI': '24.51',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6710.1919'},
#  236: {'Record No': 236,
#   'Age': '40',
#   'Gender': 'female',
#   'BMI': '22.22',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '19444.2658'},
#  237: {'Record No': 237,
#   'Age': '18',
#   'Gender': 'female',
#   'BMI': '26.73',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '1615.7667'},
#  238: {'Record No': 238,
#   'Age': '31',
#   'Gender': 'male',
#   'BMI': '38.39',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '4463.2051'},
#  239: {'Record No': 239,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '29.07',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '17352.6803'},
#  240: {'Record No': 240,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '38.06',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '7152.6714'},
#  241: {'Record No': 241,
#   'Age': '23',
#   'Gender': 'female',
#   'BMI': '36.67',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '38511.6283'},
#  242: {'Record No': 242,
#   'Age': '33',
#   'Gender': 'female',
#   'BMI': '22.135',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '5354.07465'},
#  243: {'Record No': 243,
#   'Age': '55',
#   'Gender': 'female',
#   'BMI': '26.8',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '35160.13457'},
#  244: {'Record No': 244,
#   'Age': '40',
#   'Gender': 'male',
#   'BMI': '35.3',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7196.867'},
#  245: {'Record No': 245,
#   'Age': '63',
#   'Gender': 'female',
#   'BMI': '27.74',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '29523.1656'},
#  246: {'Record No': 246,
#   'Age': '54',
#   'Gender': 'male',
#   'BMI': '30.02',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '24476.47851'},
#  247: {'Record No': 247,
#   'Age': '60',
#   'Gender': 'female',
#   'BMI': '38.06',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '12648.7034'},
#  248: {'Record No': 248,
#   'Age': '24',
#   'Gender': 'male',
#   'BMI': '35.86',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '1986.9334'},
#  249: {'Record No': 249,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '20.9',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1832.094'},
#  250: {'Record No': 250,
#   'Age': '29',
#   'Gender': 'male',
#   'BMI': '28.975',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4040.55825'},
#  251: {'Record No': 251,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '17.29',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '12829.4551'},
#  252: {'Record No': 252,
#   'Age': '63',
#   'Gender': 'female',
#   'BMI': '32.2',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '47305.305'},
#  253: {'Record No': 253,
#   'Age': '54',
#   'Gender': 'male',
#   'BMI': '34.21',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '44260.7499'},
#  254: {'Record No': 254,
#   'Age': '27',
#   'Gender': 'male',
#   'BMI': '30.3',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '4260.744'},
#  255: {'Record No': 255,
#   'Age': '50',
#   'Gender': 'male',
#   'BMI': '31.825',
# ...
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2473.3341'},
#  917: {'Record No': 917,
#   'Age': '43',
#   'Gender': 'female',
#   'BMI': '26.885',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '21774.32215'},
#  918: {'Record No': 918,
#   'Age': '45',
#   'Gender': 'male',
#   'BMI': '22.895',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '35069.37452'},
#  919: {'Record No': 919,
#   'Age': '61',
#   'Gender': 'female',
#   'BMI': '28.2',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '13041.921'},
#  920: {'Record No': 920,
#   'Age': '35',
#   'Gender': 'female',
#   'BMI': '34.21',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '5245.2269'},
#  921: {'Record No': 921,
#   'Age': '62',
#   'Gender': 'female',
#   'BMI': '25',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '13451.122'},
#  922: {'Record No': 922,
#   'Age': '62',
#   'Gender': 'female',
#   'BMI': '33.2',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '13462.52'},
#  923: {'Record No': 923,
#   'Age': '38',
#   'Gender': 'male',
#   'BMI': '31',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '5488.262'},
#  924: {'Record No': 924,
#   'Age': '34',
#   'Gender': 'male',
#   'BMI': '35.815',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '4320.41085'},
#  925: {'Record No': 925,
#   'Age': '43',
#   'Gender': 'male',
#   'BMI': '23.2',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '6250.435'},
#  926: {'Record No': 926,
#   'Age': '50',
#   'Gender': 'male',
#   'BMI': '32.11',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '25333.33284'},
#  927: {'Record No': 927,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '23.4',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '2913.569'},
#  928: {'Record No': 928,
#   'Age': '57',
#   'Gender': 'female',
#   'BMI': '20.1',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '12032.326'},
#  929: {'Record No': 929,
#   'Age': '62',
#   'Gender': 'female',
#   'BMI': '39.16',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '13470.8044'},
#  930: {'Record No': 930,
#   'Age': '41',
#   'Gender': 'male',
#   'BMI': '34.21',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '6289.7549'},
#  931: {'Record No': 931,
#   'Age': '26',
#   'Gender': 'male',
#   'BMI': '46.53',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2927.0647'},
#  932: {'Record No': 932,
#   'Age': '39',
#   'Gender': 'female',
#   'BMI': '32.5',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '6238.298'},
#  933: {'Record No': 933,
#   'Age': '46',
#   'Gender': 'male',
#   'BMI': '25.8',
#   'No. of children': '5',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '10096.97'},
#  934: {'Record No': 934,
#   'Age': '45',
#   'Gender': 'female',
#   'BMI': '35.3',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7348.142'},
#  935: {'Record No': 935,
#   'Age': '32',
#   'Gender': 'male',
#   'BMI': '37.18',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '4673.3922'},
#  936: {'Record No': 936,
#   'Age': '59',
#   'Gender': 'female',
#   'BMI': '27.5',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '12233.828'},
#  937: {'Record No': 937,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '29.735',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '32108.66282'},
#  938: {'Record No': 938,
#   'Age': '39',
#   'Gender': 'female',
#   'BMI': '24.225',
#   'No. of children': '5',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '8965.79575'},
#  939: {'Record No': 939,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '26.18',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2304.0022'},
#  940: {'Record No': 940,
#   'Age': '53',
#   'Gender': 'male',
#   'BMI': '29.48',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '9487.6442'},
#  941: {'Record No': 941,
#   'Age': '18',
#   'Gender': 'male',
#   'BMI': '23.21',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '1121.8739'},
#  942: {'Record No': 942,
#   'Age': '50',
#   'Gender': 'female',
#   'BMI': '46.09',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '9549.5651'},
#  943: {'Record No': 943,
#   'Age': '18',
#   'Gender': 'female',
#   'BMI': '40.185',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '2217.46915'},
#  944: {'Record No': 944,
#   'Age': '19',
#   'Gender': 'male',
#   'BMI': '22.61',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '1628.4709'},
#  945: {'Record No': 945,
#   'Age': '62',
#   'Gender': 'male',
#   'BMI': '39.93',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '12982.8747'},
#  946: {'Record No': 946,
#   'Age': '56',
#   'Gender': 'female',
#   'BMI': '35.8',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '11674.13'},
#  947: {'Record No': 947,
#   'Age': '42',
#   'Gender': 'male',
#   'BMI': '35.8',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7160.094'},
#  948: {'Record No': 948,
#   'Age': '37',
#   'Gender': 'male',
#   'BMI': '34.2',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '39047.285'},
#  949: {'Record No': 949,
#   'Age': '42',
#   'Gender': 'male',
#   'BMI': '31.255',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '6358.77645'},
#  950: {'Record No': 950,
#   'Age': '25',
#   'Gender': 'male',
#   'BMI': '29.7',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '19933.458'},
#  951: {'Record No': 951,
#   'Age': '57',
#   'Gender': 'male',
#   'BMI': '18.335',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '11534.87265'},
#  952: {'Record No': 952,
#   'Age': '51',
#   'Gender': 'male',
#   'BMI': '42.9',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '47462.894'},
#  953: {'Record No': 953,
#   'Age': '30',
#   'Gender': 'female',
#   'BMI': '28.405',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '4527.18295'},
#  954: {'Record No': 954,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '30.2',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '38998.546'},
#  955: {'Record No': 955,
#   'Age': '34',
#   'Gender': 'male',
#   'BMI': '27.835',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '20009.63365'},
#  956: {'Record No': 956,
#   'Age': '31',
#   'Gender': 'male',
#   'BMI': '39.49',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '3875.7341'},
#  957: {'Record No': 957,
#   'Age': '54',
#   'Gender': 'male',
#   'BMI': '30.8',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '41999.52'},
#  958: {'Record No': 958,
#   'Age': '24',
#   'Gender': 'male',
#   'BMI': '26.79',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '12609.88702'},
#  959: {'Record No': 959,
#   'Age': '43',
#   'Gender': 'male',
#   'BMI': '34.96',
#   'No. of children': '1',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '41034.2214'},
#  960: {'Record No': 960,
#   'Age': '48',
#   'Gender': 'male',
#   'BMI': '36.67',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '28468.91901'},
#  961: {'Record No': 961,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '39.615',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2730.10785'},
#  962: {'Record No': 962,
#   'Age': '29',
#   'Gender': 'female',
#   'BMI': '25.9',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '3353.284'},
#  963: {'Record No': 963,
#   'Age': '63',
#   'Gender': 'female',
#   'BMI': '35.2',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '14474.675'},
#  964: {'Record No': 964,
#   'Age': '46',
#   'Gender': 'male',
#   'BMI': '24.795',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '9500.57305'},
#  965: {'Record No': 965,
#   'Age': '52',
#   'Gender': 'male',
#   'BMI': '36.765',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '26467.09737'},
#  966: {'Record No': 966,
#   'Age': '35',
#   'Gender': 'male',
#   'BMI': '27.1',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '4746.344'},
#  967: {'Record No': 967,
#   'Age': '51',
#   'Gender': 'male',
#   'BMI': '24.795',
#   'No. of children': '2',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '23967.38305'},
#  968: {'Record No': 968,
#   'Age': '44',
#   'Gender': 'male',
#   'BMI': '25.365',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '7518.02535'},
#  969: {'Record No': 969,
#   'Age': '21',
#   'Gender': 'male',
#   'BMI': '25.745',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '3279.86855'},
#  970: {'Record No': 970,
#   'Age': '39',
#   'Gender': 'female',
#   'BMI': '34.32',
#   'No. of children': '5',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '8596.8278'},
#  971: {'Record No': 971,
#   'Age': '50',
#   'Gender': 'female',
#   'BMI': '28.16',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '10702.6424'},
#  972: {'Record No': 972,
#   'Age': '34',
#   'Gender': 'female',
#   'BMI': '23.56',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4992.3764'},
#  973: {'Record No': 973,
#   'Age': '22',
#   'Gender': 'female',
#   'BMI': '20.235',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '2527.81865'},
#  974: {'Record No': 974,
#   'Age': '19',
#   'Gender': 'female',
#   'BMI': '40.5',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '1759.338'},
#  975: {'Record No': 975,
#   'Age': '26',
#   'Gender': 'male',
#   'BMI': '35.42',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2322.6218'},
#  976: {'Record No': 976,
#   'Age': '29',
#   'Gender': 'male',
#   'BMI': '22.895',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '16138.76205'},
#  977: {'Record No': 977,
#   'Age': '48',
#   'Gender': 'male',
#   'BMI': '40.15',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '7804.1605'},
#  978: {'Record No': 978,
#   'Age': '26',
#   'Gender': 'male',
#   'BMI': '29.15',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '2902.9065'},
#  979: {'Record No': 979,
#   'Age': '45',
#   'Gender': 'female',
#   'BMI': '39.995',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '9704.66805'},
#  980: {'Record No': 980,
#   'Age': '36',
#   'Gender': 'female',
#   'BMI': '29.92',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '4889.0368'},
#  981: {'Record No': 981,
#   'Age': '54',
#   'Gender': 'male',
#   'BMI': '25.46',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '25517.11363'},
#  982: {'Record No': 982,
#   'Age': '34',
#   'Gender': 'male',
#   'BMI': '21.375',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4500.33925'},
#  983: {'Record No': 983,
#   'Age': '31',
#   'Gender': 'male',
#   'BMI': '25.9',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '19199.944'},
#  984: {'Record No': 984,
#   'Age': '27',
#   'Gender': 'female',
#   'BMI': '30.59',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '16796.41194'},
#  985: {'Record No': 985,
#   'Age': '20',
#   'Gender': 'male',
#   'BMI': '30.115',
#   'No. of children': '5',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4915.05985'},
#  986: {'Record No': 986,
#   'Age': '44',
#   'Gender': 'female',
#   'BMI': '25.8',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7624.63'},
#  987: {'Record No': 987,
#   'Age': '43',
#   'Gender': 'male',
#   'BMI': '30.115',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '8410.04685'},
#  988: {'Record No': 988,
#   'Age': '45',
#   'Gender': 'female',
#   'BMI': '27.645',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '28340.18885'},
#  989: {'Record No': 989,
#   'Age': '34',
#   'Gender': 'male',
#   'BMI': '34.675',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '4518.82625'},
#  990: {'Record No': 990,
#   'Age': '24',
#   'Gender': 'female',
#   'BMI': '20.52',
#   'No. of children': '0',
#   'Smoker': 'yes',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '14571.8908'},
#  991: {'Record No': 991,
#   'Age': '26',
#   'Gender': 'female',
#   'BMI': '19.8',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '3378.91'},
#  992: {'Record No': 992,
#   'Age': '38',
#   'Gender': 'female',
#   'BMI': '27.835',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '7144.86265'},
#  993: {'Record No': 993,
#   'Age': '50',
#   'Gender': 'female',
#   'BMI': '31.6',
#   'No. of children': '2',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '10118.424'},
#  994: {'Record No': 994,
#   'Age': '38',
#   'Gender': 'male',
#   'BMI': '28.27',
#   'No. of children': '1',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '5484.4673'},
#  995: {'Record No': 995,
#   'Age': '27',
#   'Gender': 'female',
#   'BMI': '20.045',
#   'No. of children': '3',
#   'Smoker': 'yes',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '16420.49455'},
#  996: {'Record No': 996,
#   'Age': '39',
#   'Gender': 'female',
#   'BMI': '23.275',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '7986.47525'},
#  997: {'Record No': 997,
#   'Age': '39',
#   'Gender': 'female',
#   'BMI': '34.1',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'southwest',
#   'Yearly Insurance Cost': '7418.522'},
#  998: {'Record No': 998,
#   'Age': '63',
#   'Gender': 'female',
#   'BMI': '36.85',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'southeast',
#   'Yearly Insurance Cost': '13887.9685'},
#  999: {'Record No': 999,
#   'Age': '33',
#   'Gender': 'female',
#   'BMI': '36.29',
#   'No. of children': '3',
#   'Smoker': 'no',
#   'Region': 'northeast',
#   'Yearly Insurance Cost': '6551.7501'},
#  1000: {'Record No': 1000,
#   'Age': '36',
#   'Gender': 'female',
#   'BMI': '26.885',
#   'No. of children': '0',
#   'Smoker': 'no',
#   'Region': 'northwest',
#   'Yearly Insurance Cost': '5267.81815'},
#  ...}

# %% [markdown]
# The `compile_dictionary()` method is run and the results are shown above. All the data is now compactly and neatly stored in a single dictionary, which will serve as a valuable tool for further analysis should I wish to investigate deeper into the other attributes in **insurance.csv** at a later period of time.

# %%
person_info.analyze_ages()
# Out:
# 'Average age: 39.20702541106129 years'

# %% [markdown]
# The `analyze_ages()` method is run and the results show that the average age of a health insurance policy holder is around 39 years. This is important to check because we want to know what if the data in **insurance.csv** is representative for a broader population. If we decide to use the dataset to make inferences about other populations, we must make sure that the data is abundant and broad enough for such use cases.
#
# We would have to do further analysis to make sure the range and standard deviation of the patient age group in **insurance.csv** is indicative of a random sampling of individuals.

# %%
person_info.analyze_insurance_cost()
# Out:
# 'Average yearly insurance cost: 13270.422265141257 dollars'

# %% [markdown]
# The `analyze_insurance_cost()` method is run and the results above show that on average, a health insurance policy holder spends around $13,270 annually on premium payments. This is a valuable piece of information as it can be used by a variety of stakeholders. For instance, it could be used to evaluate the profitability and success of the health insurance industry in the US. Alternatively, performing additional analysis into areas such as identifying correlations between costs and gender, costs and region, or costs and number of children will help to generate more specific findings with a clearly targeted scope of interest.

# %%
person_info.analyze_gender()
# Out:
# Number of females:  662
# Number of males:  676

# %% [markdown]
# The `analyze_gender()` method is run and the results show that, of the sample data, there were a total of **662 female policy holders** and a total of **676 male policy holders** of health insurance. There seems to be a good balance of the genders which hint at a good representation of the overall population, as well as good collection of data. A balance in the classes is vital should the dataset be used to build a classification model in the future.
